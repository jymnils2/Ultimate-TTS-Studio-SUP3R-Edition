# %%
#pip install uv
# !curl -LsSf https://astral.sh/uv/install.sh | sh
# Para que el comando sea reconocido inmediatamente en el entorno actual
import os
os.environ["PATH"] += ":/root/.cargo/bin"
# Out:
# downloading uv 0.9.24 x86_64-unknown-linux-gnu
# no checksums to verify
# installing to /usr/local/bin
#   uv
#   uvx
# everything's installed!

# %%
# !git clone https://github.com/SUP3RMASS1VE/Ultimate-TTS-Studio-SUP3R-Edition.git
# %cd Ultimate-TTS-Studio-SUP3R-Edition
# Out:
# Cloning into 'Ultimate-TTS-Studio-SUP3R-Edition'...
# remote: Enumerating objects: 1888, done.
# remote: Counting objects: 100% (136/136), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 1888 (delta 129), reused 93 (delta 93), pack-reused 1752 (from 2)
# Receiving objects: 100% (1888/1888), 63.08 MiB | 13.83 MiB/s, done.
# Resolving deltas: 100% (790/790), done.
# /content/Ultimate-TTS-Studio-SUP3R-Edition

# %%
# Instalamos las dependencias del sistema necesarias para audio y compilación
# !apt-get update && apt-get install -y llvm-dev portaudio19-dev libprotobuf-dev protobuf-compiler

# Le decimos a uv que use Python 3.10 y que instale los requerimientos
# !uv venv --python 3.10
# Out:
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:6 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:8 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:9 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Fetched 3,917 B in 1s (2,996 B/s)
# Reading package lists... Done
# ...

# %%
# Instalación usando el Python 3.10 del entorno virtual
# !uv pip install --python .venv/bin/python -r requirements.txt
# Out:
# Resolved 345 packages in 8.85s
# Prepared 227 packages in 1m 38s
# Installed 345 packages in 1.60s
#  + absl-py==2.3.1
#  + accelerate==1.12.0
#  + addict==2.4.0
#  + aiobotocore==2.17.0
#  + aiofiles==24.1.0
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.13.3
#  + aioice==0.10.2
#  + aioitertools==0.13.0
#  + aiortc==1.14.0
#  + aiosignal==1.4.0
#  + aliyun-python-sdk-core==2.16.0
#  + aliyun-python-sdk-kms==2.16.5
#  + annotated-doc==0.0.4
#  + annotated-types==0.7.0
#  + antlr4-python3-runtime==4.9.3
#  + anyascii==0.3.3
#  + anyio==4.12.1
#  + argbind==0.3.9
#  + asttokens==3.0.1
#  + async-timeout==5.0.1
#  + attrs==25.4.0
#  + audioread==3.1.0
#  + av==16.1.0
#  + babel==2.17.0
#  + baize==0.23.1
#  + beautifulsoup4==4.14.3
#  + bitsandbytes==0.49.1
#  + blis==1.3.3
#  + boto3==1.35.36
#  + botocore==1.35.93
#  + cached-path==1.8.1
#  + cachetools==6.2.4
#  + catalogue==2.0.10
#  + certifi==2026.1.4
#  + cffi==2.0.0
#  + cfgv==3.5.0
#  + chardet==5.2.0
# ...

# %%
# Definimos la ruta al python del entorno virtual para no repetirla
py_env = ".venv/bin/python"

print("--- Iniciando instalación de paquetes específicos ---")

# 1. Voxcpm y OpenAI-Whisper
# !uv pip install --python {py_env} voxcpm openai-whisper --no-deps && echo "✅ voxcpm y whisper instalados."

# 2. Flash Attention (Versión para LINUX/CUDA 12)
# NOTA: He cambiado tu link de Windows por la instalación estándar de Linux compatible con CUDA
# !uv pip install --python {py_env} flash-attn --no-build-isolation && echo "✅ Flash Attention instalado."

# 3. WeTextProcessing
# !uv pip install --python {py_env} WeTextProcessing --no-deps && echo "✅ WeTextProcessing instalado."

# 4. Triton (Versión para LINUX)
# IMPORTANTE: triton-windows NO funciona en Linux. Instalamos la versión estándar.
# !uv pip install --python {py_env} triton && echo "✅ Triton instalado."

# 5. PyTorch 2.7.0 con CUDA 12.8
# !uv pip install --python {py_env} torch==2.7.0 torchvision torchaudio --index-url https://download.pytorch.org/whl/cu128 && echo "✅ PyTorch 2.7.0 instalado con éxito."

print("\n--- ¡Todas las instalaciones han culminado! ---")

# %%
# !uv run huggingface-cli login
# Out:
# ⚠️  Warning: 'huggingface-cli login' is deprecated. Use 'hf auth login' instead.
#
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) yes
# Token is valid (permission: fineGrained).
# The token `Hugging` has been saved to /root/.cache/huggingface/stored_tokens
# ...

# %%
# !uv run hf download fishaudio/openaudio-s1-mini --local-dir checkpoints/openaudio-s1-mini
# Out:
# Fetching 7 files:   0% 0/7 [00:00<?, ?it/s]Downloading 'special_tokens.json' to 'checkpoints/openaudio-s1-mini/.cache/huggingface/download/Pdr1pnDFqf3r8xSTD-lPnaCpeRA=.954449504ac94d1a89b31aa1bc914f07f898b6bb.incomplete'
# ...
#
# special_tokens.json:   0% 0.00/126k [00:00<?, ?B/s]
#
# .gitattributes: 100% 1.52k/1.52k [00:00<00:00, 7.14MB/s]
# Download complete. Moving file to checkpoints/openaudio-s1-mini/.gitattributes
# Fetching 7 files:  14% 1/7 [00:00<00:04,  1.34it/s]
#
# config.json: 100% 844/844 [00:00<00:00, 6.28MB/s]
# Download complete. Moving file to checkpoints/openaudio-s1-mini/config.json
#
#
# tokenizer.tiktoken:   0% 0.00/2.56M [00:00<?, ?B/s]
#
#
# codec.pth:   0% 0.00/1.87G [00:00<?, ?B/s]
#
#
#
# model.pth:   0% 0.00/1.74G [00:00<?, ?B/s]
# special_tokens.json: 100% 126k/126k [00:00<00:00, 581kB/s]
# Download complete. Moving file to checkpoints/openaudio-s1-mini/special_tokens.json
#
#
# tokenizer.tiktoken: 100% 2.56M/2.56M [00:01<00:00, 2.40MB/s]
# ...

# %%
# !uv run python launch.py
# Out:
# [2026-01-12 17:08:13,693] [INFO] [real_accelerator.py:239:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# ✅ F5-TTS handler loaded
# ✅ Higgs Audio loaded successfully
# ✅ Higgs Audio handler loaded
# ✅ KittenTTS package available
# ✅ KittenTTS handler loaded
# ✅ VibeVoice handler loaded
# ✅ VibeVoice handler loaded
# ✅ VoxCPM loaded successfully
# ✅ VoxCPM handler loaded
# ✅ Chatterbox Turbo handler loaded
# ✅ Chatterbox Turbo handler loaded
# ✅ Using env FFmpeg: /content/Ultimate-TTS-Studio-SUP3R-Edition/.venv/lib/python3.10/site-packages/imageio_ffmpeg/binaries/ffmpeg-linux-x86_64-v7.0.2
# ✅ IndexTTS loaded with models ready
# ✅ IndexTTS2 loaded successfully (Strategy 1)
# ✅ IndexTTS2 handler loaded
# 🚀 Running on device: cuda
# 🚀 TTS models ready for on-demand loading...
# 🚀 Starting Unified TTS Pro...
# Creating new F5-TTS handler instance...
# ✅ F5-TTS API loaded (new version)
# ✅ VibeVoice is available, setting up event handlers...
# ...
